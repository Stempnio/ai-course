# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)
print(p1)
# Out:
# (array([-3.57378695,  6.60463869]), array([2622.11653477]), 2, array([20.07585042,  4.25712321]))

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_f_lr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack( (np.ones_like(x), x, x**2, x**3) ).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_f_lr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4) ).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_f_lr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack( (np.ones_like(x), x, x**2, x**3, x**4, x**5) ).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_5(x_f_lr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
x1 = np.linspace(0., 3, 200)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x1, f_lr_5(x1), 'g');
plt.plot(x1, f_lr_4(x1), 'b');
plt.plot(x1, f_lr_3(x1), 'r');
plt.plot(x1, f_lr_2(x1), 'y');
plt.plot(x1, f_lr_1(x1), 'p');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.544
# Dependent Variable: y                AIC:                614.4444
# Date:               2022-03-31 22:07 BIC:                619.6547
# No. Observations:   100              Log-Likelihood:     -305.22
# Df Model:           1                F-statistic:        119.1
# Df Residuals:       98               Prob (F-statistic): 1.28e-18
# R-squared:          0.549            Scale:              26.756
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.5738     1.0846   -3.2949   0.0014   -5.7262   -1.4214
# x1         6.6046     0.6052   10.9126   0.0000    5.4036    7.8057
# -----------------------------------------------------------------
# Omnibus:              24.319       Durbin-Watson:          1.806
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       36.036
# Skew:                 1.113        Prob(JB):               0.000
# Kurtosis:             4.921        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.809
# Dependent Variable: y                AIC:                528.6348
# Date:               2022-03-31 22:07 BIC:                536.4503
# No. Observations:   100              Log-Likelihood:     -261.32
# Df Model:           2                F-statistic:        210.0
# Df Residuals:       97               Prob (F-statistic): 5.66e-36
# R-squared:          0.812            Scale:              11.234
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     5.5269     1.0493    5.2671   0.0000     3.4443    7.6096
# x1      -11.2290     1.5765   -7.1229   0.0000   -14.3579   -8.1002
# x2        5.9130     0.5063   11.6796   0.0000     4.9082    6.9179
# -----------------------------------------------------------------
# Omnibus:              5.081        Durbin-Watson:           2.091
# Prob(Omnibus):        0.079        Jarque-Bera (JB):        4.653
# Skew:                 0.523        Prob(JB):                0.098
# Kurtosis:             3.152        Condition No.:           26
# =================================================================

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.544
# Method:                 Least Squares   F-statistic:                     119.1
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):           1.28e-18
# Time:                        22:07:13   Log-Likelihood:                -305.22
# No. Observations:                 100   AIC:                             614.4
# Df Residuals:                      98   BIC:                             619.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.5738      1.085     -3.295      0.001      -5.726      -1.421
# x              6.6046      0.605     10.913      0.000       5.404       7.806
# ==============================================================================
# Omnibus:                       24.319   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.036
# Skew:                           1.113   Prob(JB):                     1.50e-08
# Kurtosis:                       4.921   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     210.0
# Date:                Thu, 31 Mar 2022   Prob (F-statistic):           5.66e-36
# Time:                        22:07:13   Log-Likelihood:                -261.32
# No. Observations:                 100   AIC:                             528.6
# Df Residuals:                      97   BIC:                             536.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.5269      1.049      5.267      0.000       3.444       7.610
# x            -11.2290      1.576     -7.123      0.000     -14.358      -8.100
# I(x ** 2)      5.9130      0.506     11.680      0.000       4.908       6.918
# ==============================================================================
# Omnibus:                        5.081   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.079   Jarque-Bera (JB):                4.653
# Skew:                           0.523   Prob(JB):                       0.0976
# Kurtosis:                       3.152   Cond. No.                         26.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
