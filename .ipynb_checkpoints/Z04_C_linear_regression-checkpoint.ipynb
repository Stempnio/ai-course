# %% [markdown]
# # Regresja liniowa
#
# Naszym Celem jest empityczne sprawdzenie twierdzenia:
#
# Niech $A \in \mathbb{R}^{N\times K}$ będzie macierzą która przekształca $\mathbb{R}^{K}$ w $\mathbb{R}^N$, i niech $y \in \mathbb{R}^{K}$.
#
# Wtedy punkt $x_0 \in \mathbb{R}^K$ spełnia
#
# $$
# x_0 = \mathrm{argmin} \{ x \in \mathbb{R}^K   \colon \| Ax - y \|^2 \}
# $$
#
# wtedy i tylko wtedy gdy
#
# $$
# A^TA x_0 = A^Ty.
# $$

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę wykres funkcji w kształcie
#
# $
# f(x)=x^2
# $
#
# na odcinku $[0,3]$ i go narysować.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: (x**2)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)=x^2$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y);
print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.71436896]
# -1.3655903186148186

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr = lambda x: lr.coef_ * x +lr.intercept_

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Teraz możemy wykonać predykcję dla punktu
# $$
# x_0 = 1.5
# $$

# %%
point = np.array([1.5])
y_point = lr.predict(point[:, np.newaxis])

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.plot(point, y_point, 'or', ms=10);
plt.show()

# %% [markdown]
# Możemy wypisać miarę dopasowania $R^2$. Narazie nie wnikamy w to co ona oznacza.

# %%
from sklearn.metrics import r2_score
print(lr.score(x[:, np.newaxis], y))
print(r2_score(lr.predict(x[:, np.newaxis]), y))
# Out:
# 0.8823626595648947
# 0.8666791492592015

# %% [markdown]
# # Zadanie 1
# Stwórz macierz postaci:
# $$
# A=\begin{bmatrix}
# x_1 & 1\\
# \ddots & \ddots\\
# x_n & 1\\
# \end{bmatrix}
# $$
#
# i rozwiąż równanie
#
# $$
# A^TA x = A^Ty.
# $$
#
# gdzie (x,y) to nasz zbiór treningowy.
#
# Użyj funkcji <tt>linalg.solve</tt>.

# %%
deg=1
A=np.vander(x, deg + 1)
A
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %%
a, b  = np.linalg.solve(np.matmul(A.T, A) , np.matmul(A.T, y))

f_lr = lambda x: a * x + b

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie 2
# Zapoznaj się z funkcją <tt>optimize.fmin_cg</tt>
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.optimize.fmin_cg.html
# i znajdż minum funkcji
#
# $$
# f(x,y) = (x+1)^2+y^2
# $$

# %%
from scipy import optimize

def f(x):
    x1, x2 = x
    return (x1+1)**2+(x2)**2
x0 = np.asarray((0, 0))  # Initial guess.
res1 = optimize.fmin_cg(f, x0)
print(res1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 9
#          Gradient evaluations: 3
# [-1.00000001e+00 -7.45058060e-09]

# %% [markdown]
# # Zadanie 3
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error}(a,b;(x,y)) =  \sum_{i=1}^{n} ( y_i - (ax_i+b) )^2.
# $$

# %%
def sqrError(x1):
    a,b = x1
    return np.sum((y-(a*x+b))**2)

# %% [markdown]
# # Zadanie 4
# Zminimalizuj funkcją $\mathrm{compute\_error}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
x0 = np.asarray((0, 0))  # Initial guess.
a1,b1 = optimize.fmin_cg(sqrError, x0)
print(a1,b1)

f_lr = lambda x: a1 * x + b1

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 4.926140
#          Iterations: 3
#          Function evaluations: 18
#          Gradient evaluations: 6
# 2.7143689800492443 -1.3655903011627644

# %% [markdown]
# # Zadanie 5
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error\_1}(a,b;(x,y)) =  \sum_{i=1}^{n} |y_i - (ax_i+b)|.
# $$

# %%
def sqrError1(x1):
    a,b = x1
    return np.sum(np.abs(y-(a*x+b)))

# %% [markdown]
# # Zadanie 6
# Zminimalizuj funkcją $\mathrm{compute\_error\_1}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
x0 = np.asarray((0,0))
a2, b2 = optimize.fmin_cg(sqrError1, x0)
print(a2,b2)

f_lr = lambda x: a2 * x + b2

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.558267
#          Iterations: 3
#          Function evaluations: 144
#          Gradient evaluations: 46
# 2.5113788132734576 -1.1281116367676813

# %% [markdown]
# # Zadanie 7
# Wykonaj dwie powyższe regresję na danych z wartością odstającą.

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))/5
y[1]=y[1]+10

x0 = np.asarray((0, 0))
a3,b3 = optimize.fmin_cg(sqrError, x0)
f3 = lambda x: a3 * x + b3
x3 = np.linspace(0., 3, 200)
y3 = f3(x3)

a4,b4 = optimize.fmin_cg(sqrError1, x0)
f4 = lambda x: a4 * x + b4
x4 = np.linspace(0., 3, 200)
y4 = f4(x4)

plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x3, y3, 'b', label="kwadrat")
plt.plot(x4, y4, 'r', label="modul")
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.legend()
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 78.055308
#          Iterations: 3
#          Function evaluations: 18
#          Gradient evaluations: 6
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.793203
#          Iterations: 6
#          Function evaluations: 381
#          Gradient evaluations: 123

# %%
points = np.column_stack((x,y))
# Out:
# array([[ 0.2       , -0.13049092],
#        [ 0.5       , 10.41328773],
#        [ 0.8       ,  1.03392202],
#        [ 0.9       ,  0.84775576],
#        [ 1.3       ,  1.37513198],
#        [ 1.7       ,  1.74238904],
#        [ 2.1       ,  2.02222605],
#        [ 2.7       ,  2.58024547]])
